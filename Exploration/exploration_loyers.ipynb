# %%
Chargement

# %% [markdown]
# Colonnes

# %%
import pandas as pd

df = pd.read_parquet("../data/bronze/loyers/annee=2025/loyers_2025.parquet")
print(df.shape)
df.head()
# Out:
# (3585, 24)
#   Observatory  Data_year           agglomeration Zone_complementaire  \
# 0       B2900       2025  Agglomération de Brest                 NaN
# 1       B2900       2025  Agglomération de Brest                 NaN
# 2       B2900       2025  Agglomération de Brest                 NaN
# 3       B2900       2025  Agglomération de Brest                 NaN
# 4       B2900       2025  Agglomération de Brest                 NaN
#
#   Type_habitat epoque_construction_homogene anciennete_locataire_homogene  \
# 0          NaN                          NaN                           NaN
# 1          NaN                          NaN                           NaN
# 2          NaN                          NaN                           NaN
# 3          NaN                          NaN                           NaN
# 4          NaN                          NaN                           NaN
#
#   nombre_pieces_homogene  loyer_1_decile  loyer_1_quartile  ...  \
# 0                    NaN             7.4               8.6  ...
# 1            Maison 1-3P             NaN               NaN  ...
# 2           Ensemble 4P+             6.5               7.2  ...
# 3             Maison 4P+             6.1               7.4  ...
# 4              Appart 1P            11.0              12.6  ...
#
#    loyer_mensuel_1_decile  loyer_mensuel_1_quartile  loyer_mensuel_median  \
# 0                   350.0                     434.0                 530.0
# 1                     NaN                       NaN                   NaN
# 2                   540.0                     621.0                 780.0
# 3                   667.0                     780.0                 850.0
# 4                   295.0                     327.0                 350.0
#
#    loyer_mensuel_3_quartile  loyer_mensuel_9_decile  moyenne_loyer_mensuel  \
# 0                     670.0                   840.0                  572.0
# 1                       NaN                     NaN                    NaN
# 2                     890.0                  1058.0                  782.0
# 3                     940.0                  1150.0                  886.0
# 4                     400.0                   435.0                  364.0
#
#    surface_moyenne  nombre_observations  nombre_logements  \
# 0             60.0               4341.0           27162.0
# 1              NaN                 34.0               NaN
# 2             95.0                849.0            7532.0
# 3            107.0                232.0            3101.0
# 4             26.0                696.0            3508.0
#
#    methodologie_production
# 0       Estimation directe
# 1       Estimation directe
# 2       Estimation directe
# 3       Estimation directe
# 4       Estimation directe
#
# [5 rows x 24 columns]

# %%
# Out:
#      Observatory                                      agglomeration
# 0          B2900                             Agglomération de Brest
# 198        B3000                             Agglomération de Nîmes
# 618        B3000                               Agglomération d'Alès
# 1038       B3100                          Agglomération de Toulouse
# 1458       B3400                       Agglomération de Montpellier
# 1598       B3401                              Agglomération de Sète
# 1738       B3600                       Agglomération de Châteauroux
# 1938       B6100                            Agglomération d'Alençon
# 2048       B7100                  Agglomération de Chalon-sur-Saône
# 2188       B7101                             Agglomération de Mâcon
# 2328       B7400                      Agglomération du Grand Annecy
# 2466       B7400                          Agglomération d'Annemasse
# 2606       B7400               Thonon agglomération et Pays d'Evian
# 2746       B7400                               Unité urbaine Cluses
# 2885       B7900                             Agglomération de Niort
# 3025       B7901   Communauté d'agglomération du Bocage Bressuirais
# 3165       B7902  Communautés de communes Mellois en Poitou et H...
# 3305       B8200                         Agglomération de Montauban
# 3445       B8200  Communautés de communes Terres des Confluences...

# %%
df.columns.tolist()
# Out:
# ['Observatory',
#  'Data_year',
#  'agglomeration',
#  'Zone_complementaire',
#  'Type_habitat',
#  'epoque_construction_homogene',
#  'anciennete_locataire_homogene',
#  'nombre_pieces_homogene',
#  'loyer_1_decile',
#  'loyer_1_quartile',
#  'loyer_median',
#  'loyer_3_quartile',
#  'loyer_9_decile',
#  'loyer_moyen',
#  'loyer_mensuel_1_decile',
#  'loyer_mensuel_1_quartile',
#  'loyer_mensuel_median',
#  'loyer_mensuel_3_quartile',
#  'loyer_mensuel_9_decile',
#  'moyenne_loyer_mensuel',
#  'surface_moyenne',
#  'nombre_observations',
#  'nombre_logements',
#  'methodologie_production']

# %% [markdown]
# Types

# %%
# Types
print(df.dtypes)
print("\n")
# Out:
# Observatory                          str
# Data_year                          int64
# agglomeration                        str
# Zone_complementaire                  str
# Type_habitat                         str
# epoque_construction_homogene         str
# anciennete_locataire_homogene        str
# nombre_pieces_homogene               str
# loyer_1_decile                   float64
# loyer_1_quartile                 float64
# loyer_median                     float64
# loyer_3_quartile                 float64
# loyer_9_decile                   float64
# loyer_moyen                      float64
# loyer_mensuel_1_decile           float64
# loyer_mensuel_1_quartile         float64
# loyer_mensuel_median             float64
# loyer_mensuel_3_quartile         float64
# loyer_mensuel_9_decile           float64
# moyenne_loyer_mensuel            float64
# surface_moyenne                  float64
# nombre_observations              float64
# nombre_logements                 float64
# methodologie_production              str
# dtype: object

# %% [markdown]
# Valeurs manquantes

# %%
# Valeurs manquantes
print(df.isnull().sum())
print("\n")
# Out:
# Observatory                         0
# Data_year                           0
# agglomeration                       0
# Zone_complementaire              2745
# Type_habitat                     1508
# epoque_construction_homogene     1124
# anciennete_locataire_homogene    2100
# nombre_pieces_homogene           1318
# loyer_1_decile                   1241
# loyer_1_quartile                 1241
# loyer_median                     1241
# loyer_3_quartile                 1241
# loyer_9_decile                   1241
# loyer_moyen                      1241
# loyer_mensuel_1_decile           1241
# loyer_mensuel_1_quartile         1241
# loyer_mensuel_median             1241
# loyer_mensuel_3_quartile         1241
# loyer_mensuel_9_decile           1241
# moyenne_loyer_mensuel            1241
# surface_moyenne                  1241
# nombre_observations                69
# nombre_logements                 2087
# methodologie_production           244
# dtype: int64

# %% [markdown]
# Statistiques

# %%
# Statistiques
print(df.describe())
# Out:
#        Data_year  loyer_1_decile  loyer_1_quartile  loyer_median  \
# count     3585.0     2344.000000       2344.000000   2344.000000
# mean      2025.0        8.382253          9.590486     10.979010
# std          0.0        2.205799          2.399313      2.753359
# min       2025.0        3.100000          4.400000      5.300000
# 25%       2025.0        6.700000          7.700000      8.800000
# 50%       2025.0        8.100000          9.300000     10.500000
# 75%       2025.0        9.700000         11.000000     12.600000
# max       2025.0       16.300000         17.500000     20.300000
#
#        loyer_3_quartile  loyer_9_decile  loyer_moyen  loyer_mensuel_1_decile  \
# count       2344.000000     2344.000000  2344.000000             2344.000000
# mean          12.576493       14.324872    10.799957              494.601109
# std            3.264513        3.897834     2.736722              148.324378
# min            6.600000        7.200000     5.200000              220.000000
# 25%           10.000000       11.400000     8.600000              390.000000
# 50%           11.900000       13.600000    10.300000              465.000000
# 75%           14.400000       16.700000    12.400000              576.750000
# max           23.800000       28.300000    19.400000             1621.000000
#
#        loyer_mensuel_1_quartile  loyer_mensuel_median  \
# count               2344.000000           2344.000000
# mean                 568.354522            660.753413
# std                  172.740696            211.534841
# min                  250.000000            287.000000
# 25%                  450.000000            520.000000
# 50%                  529.000000            610.000000
# 75%                  653.000000            769.000000
# max                 1700.000000           2100.000000
#
#        loyer_mensuel_3_quartile  loyer_mensuel_9_decile  \
# count               2344.000000             2344.000000
# mean                 771.012799              896.963737
# std                  266.139109              341.624087
# min                  321.000000              341.000000
# 25%                  592.000000              652.750000
# 50%                  721.000000              823.500000
# 75%                  880.000000             1043.000000
# max                 2266.000000             2520.000000
#
#        moyenne_loyer_mensuel  surface_moyenne  nombre_observations  \
# count            2344.000000      2344.000000          3516.000000
# mean              682.161689        66.334898           674.686860
# std               222.563421        22.723731          2140.198674
# min               288.000000        21.000000             1.000000
# 25%               531.000000        48.000000            43.000000
# 50%               638.000000        65.000000           125.000000
# 75%               789.000000        87.000000           420.000000
# max              2077.000000       129.000000         39064.000000
#
#        nombre_logements
# count       1498.000000
# mean        4120.538718
# std        10047.475299
# min           18.000000
# 25%          651.750000
# 50%         1388.000000
# 75%         3537.750000
# max       172235.000000

# %% [markdown]
# Comprendre les nulls sur loyer_mensuel_median

# %%
# Regarder les lignes où loyer_mensuel_median est null
df_null = df[df["loyer_mensuel_median"].isna()]
print(df_null[["agglomeration", "Type_habitat", "nombre_pieces_homogene", "nombre_observations"]].head(20))
# Out:
#              agglomeration Type_habitat nombre_pieces_homogene  \
# 1   Agglomération de Brest          NaN            Maison 1-3P
# 27  Agglomération de Brest          NaN            Maison 1-3P
# 28  Agglomération de Brest          NaN             Maison 4P+
# 29  Agglomération de Brest          NaN              Appart 1P
# 31  Agglomération de Brest          NaN              Appart 3P
# 32  Agglomération de Brest          NaN             Appart 4P+
# 34  Agglomération de Brest          NaN            Maison 1-3P
# 35  Agglomération de Brest          NaN             Maison 4P+
# 38  Agglomération de Brest          NaN              Appart 3P
# 39  Agglomération de Brest          NaN             Appart 4P+
# 46  Agglomération de Brest          NaN             Maison 4P+
# 52  Agglomération de Brest          NaN            Maison 1-3P
# 53  Agglomération de Brest          NaN             Maison 4P+
# 64  Agglomération de Brest          NaN             Maison 4P+
# 66  Agglomération de Brest          NaN              Appart 2P
# 67  Agglomération de Brest          NaN              Appart 3P
# 68  Agglomération de Brest          NaN             Appart 4P+
# 70  Agglomération de Brest          NaN            Maison 1-3P
# 71  Agglomération de Brest          NaN             Maison 4P+
# 77  Agglomération de Brest          NaN           Ensemble 4P+
#
#     nombre_observations
# 1                  34.0
# 27                  2.0
# 28                  5.0
# 29                 45.0
# 31                 26.0
# 32                  8.0
# 34                  7.0
# 35                 15.0
# 38                 46.0
# 39                 23.0
# 46                  7.0
# 52                  5.0
# 53                 28.0
# 64                  1.0
# 66                 44.0
# 67                 30.0
# 68                 20.0
# 70                  2.0
# 71                 23.0
# 77                 47.0

# %% [markdown]
# Filtrage

# %%
# Je garde seulement les lignes qui ont un loyer médian
df_clean = df[df["loyer_mensuel_median"].notna()].copy()

print(f"Avant : {len(df)} lignes")
print(f"Après : {len(df_clean)} lignes")
# Out:
# Avant : 3585 lignes
# Après : 2344 lignes

# %% [markdown]
# Vérifier le niveau géographique

# %% [markdown]
# Colonnes utiles

# %%
cols_utiles = [
    "Observatory",
    "Data_year",
    "agglomeration",
    "Type_habitat",
    "nombre_pieces_homogene",
    "loyer_median",
    "loyer_mensuel_median",
    "surface_moyenne",
    "nombre_observations",
]

df_cols_utiles = df_clean[cols_utiles].copy()
print(df_cols_utiles.shape)
df_cols_utiles.head()
# Out:
# (2344, 9)
#   Observatory  Data_year           agglomeration Type_habitat  \
# 0       B2900       2025  Agglomération de Brest          NaN
# 2       B2900       2025  Agglomération de Brest          NaN
# 3       B2900       2025  Agglomération de Brest          NaN
# 4       B2900       2025  Agglomération de Brest          NaN
# 5       B2900       2025  Agglomération de Brest          NaN
#
#   nombre_pieces_homogene  loyer_median  loyer_mensuel_median  surface_moyenne  \
# 0                    NaN          10.0                 530.0             60.0
# 2           Ensemble 4P+           8.4                 780.0             95.0
# 3             Maison 4P+           8.6                 850.0            107.0
# 4              Appart 1P          14.5                 350.0             26.0
# 5              Appart 2P          11.1                 473.0             43.0
#
#    nombre_observations
# 0               4341.0
# 2                849.0
# 3                232.0
# 4                696.0
# 5               1517.0

# %% [markdown]
#  Graphiques Plotly

# %%
import plotly.express as px

# Distribution du loyer mensuel médian
fig = px.histogram(
    df_cols_utiles,
    x="loyer_mensuel_median",
    color="Type_habitat",
    nbins=50,
    title="Distribution du loyer mensuel médian par type de bien",
    labels={
        "loyer_mensuel_median": "Loyer mensuel médian (€)",
        "Type_habitat": "Type de bien"
    }
)
fig.show()

# Boxplot loyer mensuel par type de bien
fig = px.box(
    df_cols_utiles,
    x="Type_habitat",
    y="loyer_mensuel_median",
    color="Type_habitat",
    title="Distribution du loyer mensuel médian par type de bien",
    labels={
        "loyer_mensuel_median": "Loyer mensuel médian (€)",
        "Type_habitat": "Type de bien"
    }
)
fig.show()

# Top 10 agglomérations par loyer médian
top10 = (
    df_cols_utiles.groupby("agglomeration")["loyer_mensuel_median"]
    .median()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

fig = px.bar(
    top10,
    x="agglomeration",
    y="loyer_mensuel_median",
    title="Top 10 agglomérations par loyer mensuel médian",
    labels={
        "loyer_mensuel_median": "Loyer médian (€)",
        "agglomeration": "Agglomération"
    },
    color="loyer_mensuel_median",
    color_continuous_scale="Blues"
)
fig.update_layout(xaxis_tickangle=-45)
fig.show()

# %%
# Quelles agglomérations ont les loyers les plus élevés ?
df_top = df_clean[df_clean["loyer_mensuel_median"] > 957].sort_values(
    "loyer_mensuel_median", ascending=False
)
print(df_top[["agglomeration", "Type_habitat", "loyer_mensuel_median", "nombre_observations"]].head(20))
# Out:
#                              agglomeration Type_habitat  loyer_mensuel_median  \
# 2548             Agglomération d'Annemasse       Maison                2100.0
# 2546             Agglomération d'Annemasse       Maison                2070.0
# 2550             Agglomération d'Annemasse       Maison                2031.0
# 2509             Agglomération d'Annemasse          NaN                1700.0
# 2478             Agglomération d'Annemasse          NaN                1685.0
# 2469             Agglomération d'Annemasse          NaN                1670.0
# 2524             Agglomération d'Annemasse       Maison                1670.0
# 2516             Agglomération d'Annemasse          NaN                1632.0
# 2565             Agglomération d'Annemasse  Appartement                1570.0
# 2618  Thonon agglomération et Pays d'Evian          NaN                1550.0
# 2603             Agglomération d'Annemasse  Appartement                1510.0
# 2691  Thonon agglomération et Pays d'Evian       Maison                1500.0
# 2693  Thonon agglomération et Pays d'Evian       Maison                1500.0
# 2695  Thonon agglomération et Pays d'Evian       Maison                1500.0
# 2386         Agglomération du Grand Annecy       Maison                1470.0
# 2331         Agglomération du Grand Annecy          NaN                1470.0
# 2530             Agglomération d'Annemasse       Maison                1451.0
# 2522             Agglomération d'Annemasse       Maison                1422.0
# 2340         Agglomération du Grand Annecy          NaN                1400.0
# 2384         Agglomération du Grand Annecy       Maison                1400.0
#
#       nombre_observations
# 2548                 72.0
# 2546                 79.0
# 2550                 62.0
# 2509                153.0
# 2478                171.0
# 2469                187.0
# 2524                187.0
# 2516                318.0
# 2565                128.0
# 2618                 51.0
# 2603                291.0
# 2691                 52.0
# 2693                 51.0
# 2695                 50.0
# 2386                 62.0
# 2331                 62.0
# 2530                144.0
# 2522                217.0
# 2340                 82.0
# 2384                 69.0

# %%
print(df.columns.tolist())

# Regarder les valeurs d'agglomeration
print(df["agglomeration"].unique()[:20])
# Out:
# ['Observatory', 'Data_year', 'agglomeration', 'Zone_complementaire', 'Type_habitat', 'epoque_construction_homogene', 'anciennete_locataire_homogene', 'nombre_pieces_homogene', 'loyer_1_decile', 'loyer_1_quartile', 'loyer_median', 'loyer_3_quartile', 'loyer_9_decile', 'loyer_moyen', 'loyer_mensuel_1_decile', 'loyer_mensuel_1_quartile', 'loyer_mensuel_median', 'loyer_mensuel_3_quartile', 'loyer_mensuel_9_decile', 'moyenne_loyer_mensuel', 'surface_moyenne', 'nombre_observations', 'nombre_logements', 'methodologie_production']
# <ArrowStringArray>
# [                                          'Agglomération de Brest',
#                                            'Agglomération de Nîmes',
#                                              'Agglomération d'Alès',
#                                         'Agglomération de Toulouse',
#                                      'Agglomération de Montpellier',
#                                             'Agglomération de Sète',
#                                      'Agglomération de Châteauroux',
#                                           'Agglomération d'Alençon',
#                                 'Agglomération de Chalon-sur-Saône',
#                                            'Agglomération de Mâcon',
#                                     'Agglomération du Grand Annecy',
#                                         'Agglomération d'Annemasse',
#                              'Thonon agglomération et Pays d'Evian',
#                                              'Unité urbaine Cluses',
#                                            'Agglomération de Niort',
#                  'Communauté d'agglomération du Bocage Bressuirais',
#   'Communautés de communes Mellois en Poitou et Haut Val de Sèvres',
#                                        'Agglomération de Montauban',
#  'Communautés de communes Terres des Confluences et Grand Sud Tarn']
# Length: 19, dtype: str

# %% [markdown]
# vérifie la cohérence entre les années

# %%
annees = [2014, 2015, 2016, 2020, 2021, 2022, 2023, 2024, 2025]

for annee in annees:
    try:
        df_tmp = pd.read_parquet(f"../data/bronze/loyers/annee={annee}/loyers_{annee}.parquet")
        print(f"{annee} → {df_tmp.shape} | colonnes identiques : {df_tmp.columns.tolist() == df.columns.tolist()}")
    except Exception as e:
        print(f"{annee} → erreur : {e}")
# Out:
# 2014 → (3820, 24) | colonnes identiques : False
# 2015 → (6287, 24) | colonnes identiques : True
# 2016 → (8387, 24) | colonnes identiques : True
# 2020 → (10423, 24) | colonnes identiques : True
# 2021 → (10782, 24) | colonnes identiques : True
# 2022 → (11711, 24) | colonnes identiques : True
# 2023 → (12877, 24) | colonnes identiques : True
# 2024 → (11825, 24) | colonnes identiques : True
# 2025 → (3585, 24) | colonnes identiques : True

# %% [markdown]
# 2014 a des colonnes différentes — vérifions lesquelles :

# %%
df_2014 = pd.read_parquet("../data/bronze/loyers/annee=2014/loyers_2014.parquet")

# Colonnes dans 2025 mais pas dans 2014
print("Colonnes manquantes en 2014 :")
print(set(df.columns) - set(df_2014.columns))

# Colonnes dans 2014 mais pas dans 2025
print("\nColonnes en plus en 2014 :")
print(set(df_2014.columns) - set(df.columns))
# Out:
# Colonnes manquantes en 2014 :
# {'nombre_observations'}
#
# Colonnes en plus en 2014 :
# {'nombre_obsservations'}

# %%
# CONCLUSIONS EXPLORATION LOYERS
# ================================
# Source déjà agrégée par agglomération — pas de code INSEE
# Colonnes utiles : Observatory, Data_year, agglomeration, Type_habitat,
#                   nombre_pieces_homogene, loyer_median, loyer_mensuel_median,
#                   surface_moyenne, nombre_observations
#
# Problème principal : jointure avec DVF/INSEE difficile
#   → Les loyers sont par agglomération, DVF/INSEE par commune

#
# Incohérence entre années :
#   → 2014 : faute de frappe "nombre_obsservations" → à renommer en Silver
#   → 2025 : seulement 3585 lignes vs 11825 en 2024 
#
# Filtres à appliquer en Silver :
#   → loyer_mensuel_median notna()
#
# Pas de valeurs aberrantes détectées
# Pas de conversions de types nécessaires
